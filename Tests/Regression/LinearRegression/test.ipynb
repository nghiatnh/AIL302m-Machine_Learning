# %%
import numpy as np
from typing import *
import matplotlib.pyplot as plt
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '/home/nghiatnh/Study/Sem5/AIL302m/Projects/AIL302m-Machine_Learning/')

from Modules.regression.linear_regression import LinearRegression
import pandas as pd

# %%
data_train = pd.read_csv(sys.path[1] + "/Tests/Data/HousePricing/train.csv")
data_train = data_train[:100]
Y_train = np.array(data_train["SalePrice"]) / 10000
Y_train.reshape((Y_train.shape[0], 1))
X_train = np.array(data_train[["LotArea"]]) / 10000
data_test = pd.read_csv(sys.path[1] + "/Tests/Data/HousePricing/test.csv")

# %%
X_train = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
Y_train = np.array([[ 49, 50, 51,  54, 58, 59, 60, 62, 63, 64, 66, 67, 68]]).T

LR = LinearRegression()
LR.fit(X_train, Y_train, l=1000, method="")

# %%
LR.score(X_train, Y_train)
# Out:
# 2.6997703983243357

# %%
LR.costs
# Out:
# [928.4934091838131,
#  486.47417440452006,
#  256.6159520964885,
#  137.08540182729433,
#  74.92729277963683,
#  42.603920121232974,
#  25.79516522119121,
#  17.054300080510185,
#  12.508887653068898,
#  10.145188659256046,
#  8.916021224207743,
#  8.276831298575983,
#  7.94444064963985,
#  7.771591330125004,
#  7.681706468895888,
#  7.634964668863598,
#  7.610658062984238,
#  7.598018175291224,
#  7.59144519802082,
#  7.585716728632576,
#  7.584361110046391,
#  7.584324428038394,
#  7.584323933643076]

# %%
plt.plot(LR.X[:,1], LR.Y, 'ro')
plt.show()
plt.plot(X_train, LR.predict(X_train), 'ro')
plt.show()
plt.plot(Y_train, LR.predict(X_train), 'ro')
plt.plot([Y_train.min(), Y_train.max()], [Y_train.min(), Y_train.max()], 'g-')
plt.show()

# %%
plt.plot([x for x in range(len(LR.costs))], LR.costs)

# %%
# LR.score(X_train, Y_train)
X_train
# Out:
# array([[147],
#        [150],
#        [153],
#        [158],
#        [163],
#        [165],
#        [168],
#        [170],
#        [173],
#        [175],
#        [178],
#        [180],
#        [183]])
